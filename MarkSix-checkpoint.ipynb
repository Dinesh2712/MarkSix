# %%
import numpy as np
import pandas as pd

# %%
mark = pd.read_csv(r"C:\Users\Don\Downloads\Mark Six.csv")

# %%
mark
# Out:
#         Draw        Date  Winning Number 1   2   3   4   5   6  Extra Number   \
# 0     23/075  2023-07-04                 5  15  20  29  32  37             18
# 1     23/074  2023-07-02                 3   6  25  29  35  42             36
# 2     23/073  2023-06-29                 6  10  18  21  22  33              4
# 3     23/072  2023-06-27                 7  10  16  18  29  45              1
# 4     23/071  2023-06-24                 1  11  14  16  26  36             39
# ...      ...         ...               ...  ..  ..  ..  ..  ..            ...
# 2148  08/005  2008-01-13                 8  13  18  22  26  42             43
# 2149  08/004  2008-01-10                 4  20  36  42  46  47             22
# 2150  08/003  2008-01-08                 2   9  14  24  40  45              3
# 2151  08/002  2008-01-05                 3  11  14  32  33  42             15
# 2152  08/001  2008-01-03                 5   8  36  39  42  46             14
#
# ...

# %%
mark.columns
# Out:
# Index(['Draw', 'Date', 'Winning Number 1', '2', '3', '4', '5', '6',
#        'Extra Number ', 'From Last', 'Same As Day', 'Odd', 'Even', ' 1-10',
#        ' 11-20', ' 21-30', ' 31-40', ' 41-50', 'Division 1 Winners',
#        'Division 1 Prize', 'Division 2 Winners', 'Division 2 Prize',
#        'Division 3 Winners', 'Division 3 Prize', 'Division 4 Winners',
#        'Division 4 Prize', 'Division 5 Winners', 'Division 5 Prize',
#        'Division 6 Winners', 'Division 6 Prize', 'Division 7 Winners',
#        'Division 7 Prize', 'Turnover'],
#       dtype='object')

# %%
ABC = mark.drop(['Division 5 Winners'], axis=1)

# %%
ABC
# Out:
#         Draw        Date  Winning Number 1   2   3   4   5   6  Extra Number   \
# 0     23/075  2023-07-04                 5  15  20  29  32  37             18
# 1     23/074  2023-07-02                 3   6  25  29  35  42             36
# 2     23/073  2023-06-29                 6  10  18  21  22  33              4
# 3     23/072  2023-06-27                 7  10  16  18  29  45              1
# 4     23/071  2023-06-24                 1  11  14  16  26  36             39
# ...      ...         ...               ...  ..  ..  ..  ..  ..            ...
# 2148  08/005  2008-01-13                 8  13  18  22  26  42             43
# 2149  08/004  2008-01-10                 4  20  36  42  46  47             22
# 2150  08/003  2008-01-08                 2   9  14  24  40  45              3
# 2151  08/002  2008-01-05                 3  11  14  32  33  42             15
# 2152  08/001  2008-01-03                 5   8  36  39  42  46             14
#
# ...

# %%
mark = mark.drop(['Division 4 Winners', 'Division 5 Winners', 'Division 6 Winners', 'Division 7 Winners', 'Division 7 Prize', 'Division 6 Prize', 'Division 5 Prize', 'Division 4 Prize'], axis=1)

# %%
mark
# Out:
#         Draw        Date  Winning Number 1   2   3   4   5   6  Extra Number   \
# 0     23/075  2023-07-04                 5  15  20  29  32  37             18
# 1     23/074  2023-07-02                 3   6  25  29  35  42             36
# 2     23/073  2023-06-29                 6  10  18  21  22  33              4
# 3     23/072  2023-06-27                 7  10  16  18  29  45              1
# 4     23/071  2023-06-24                 1  11  14  16  26  36             39
# ...      ...         ...               ...  ..  ..  ..  ..  ..            ...
# 2148  08/005  2008-01-13                 8  13  18  22  26  42             43
# 2149  08/004  2008-01-10                 4  20  36  42  46  47             22
# 2150  08/003  2008-01-08                 2   9  14  24  40  45              3
# 2151  08/002  2008-01-05                 3  11  14  32  33  42             15
# 2152  08/001  2008-01-03                 5   8  36  39  42  46             14
#
# ...

# %%
mark = mark.drop(['Draw','Turnover'], axis=1)

# %%
mark = mark.drop(['Same As Day','From Last'], axis=1)

# %%
mark = mark.drop(['Odd','Even'], axis=1)

# %%
mark
# Out:
#             Date  Winning Number 1   2   3   4   5   6  Extra Number    1-10  \
# 0     2023-07-04                 5  15  20  29  32  37             18      1
# 1     2023-07-02                 3   6  25  29  35  42             36      2
# 2     2023-06-29                 6  10  18  21  22  33              4      2
# 3     2023-06-27                 7  10  16  18  29  45              1      2
# 4     2023-06-24                 1  11  14  16  26  36             39      1
# ...          ...               ...  ..  ..  ..  ..  ..            ...    ...
# 2148  2008-01-13                 8  13  18  22  26  42             43      1
# 2149  2008-01-10                 4  20  36  42  46  47             22      1
# 2150  2008-01-08                 2   9  14  24  40  45              3      2
# 2151  2008-01-05                 3  11  14  32  33  42             15      1
# 2152  2008-01-03                 5   8  36  39  42  46             14      2
#
# ...

# %%
mark.columns
# Out:
# Index(['Date', 'Winning Number 1', '2', '3', '4', '5', '6', 'Extra Number ',
#        ' 1-10', ' 11-20', ' 21-30', ' 31-40', ' 41-50', 'Division 1 Winners',
#        'Division 1 Prize', 'Division 2 Winners', 'Division 2 Prize',
#        'Division 3 Winners', 'Division 3 Prize'],
#       dtype='object')

# %%
mark = mark.drop([' 1-10', ' 11-20', ' 21-30', ' 31-40', ' 41-50'], axis=1)

# %%
mark
# Out:
#             Date  Winning Number 1   2   3   4   5   6  Extra Number   \
# 0     2023-07-04                 5  15  20  29  32  37             18
# 1     2023-07-02                 3   6  25  29  35  42             36
# 2     2023-06-29                 6  10  18  21  22  33              4
# 3     2023-06-27                 7  10  16  18  29  45              1
# 4     2023-06-24                 1  11  14  16  26  36             39
# ...          ...               ...  ..  ..  ..  ..  ..            ...
# 2148  2008-01-13                 8  13  18  22  26  42             43
# 2149  2008-01-10                 4  20  36  42  46  47             22
# 2150  2008-01-08                 2   9  14  24  40  45              3
# 2151  2008-01-05                 3  11  14  32  33  42             15
# 2152  2008-01-03                 5   8  36  39  42  46             14
#
#       Division 1 Winners  Division 1 Prize  Division 2 Winners  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mark2 = mark.drop(['Date'], axis=1)
mark2
# Out:
#       Winning Number 1   2   3   4   5   6  Extra Number   Division 1 Winners  \
# 0                    5  15  20  29  32  37             18                 0.0
# 1                    3   6  25  29  35  42             36                 0.0
# 2                    6  10  18  21  22  33              4                 2.5
# 3                    7  10  16  18  29  45              1                 0.0
# 4                    1  11  14  16  26  36             39                 0.5
# ...                ...  ..  ..  ..  ..  ..            ...                 ...
# 2148                 8  13  18  22  26  42             43                 1.0
# 2149                 4  20  36  42  46  47             22                 1.0
# 2150                 2   9  14  24  40  45              3                 1.0
# 2151                 3  11  14  32  33  42             15                 1.0
# 2152                 5   8  36  39  42  46             14                 0.0
#
# ...

# %%
mark2.columns
# Out:
# Index(['Winning Number 1', '2', '3', '4', '5', '6', 'Extra Number ',
#        'Division 1 Winners', 'Division 1 Prize', 'Division 2 Winners',
#        'Division 2 Prize', 'Division 3 Winners', 'Division 3 Prize'],
#       dtype='object')

# %%
numbers = mark2.drop(['Division 1 Winners', 'Division 1 Prize', 'Division 2 Winners',
       'Division 2 Prize', 'Division 3 Winners', 'Division 3 Prize'], axis=1)

# %%
numbers
# Out:
#       Winning Number 1   2   3   4   5   6  Extra Number
# 0                    5  15  20  29  32  37             18
# 1                    3   6  25  29  35  42             36
# 2                    6  10  18  21  22  33              4
# 3                    7  10  16  18  29  45              1
# 4                    1  11  14  16  26  36             39
# ...                ...  ..  ..  ..  ..  ..            ...
# 2148                 8  13  18  22  26  42             43
# 2149                 4  20  36  42  46  47             22
# 2150                 2   9  14  24  40  45              3
# 2151                 3  11  14  32  33  42             15
# 2152                 5   8  36  39  42  46             14
#
# [2153 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(numbers.values)
transformed_dataset = scaler.transform(numbers.values)
transformed_df = pd.DataFrame(data=transformed_dataset, index=numbers.index)

# %%
numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2153 entries, 0 to 2152
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Winning Number 1  2153 non-null   int64
#  1   2                 2153 non-null   int64
#  2   3                 2153 non-null   int64
#  3   4                 2153 non-null   int64
#  4   5                 2153 non-null   int64
#  5   6                 2153 non-null   int64
#  6   Extra Number      2153 non-null   int64
# dtypes: int64(7)
# memory usage: 117.9 KB

# %%
numbers.head()
# Out:
#    Winning Number 1   2   3   4   5   6  Extra Number
# 0                 5  15  20  29  32  37             18
# 1                 3   6  25  29  35  42             36
# 2                 6  10  18  21  22  33              4
# 3                 7  10  16  18  29  45              1
# 4                 1  11  14  16  26  36             39

# %%
transformed_df.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -0.374132  0.141519 -0.177866  0.065373 -0.487338 -0.973743 -0.487808
# 1 -0.721407 -1.119268  0.447249  0.065373 -0.086304 -0.138896  0.776623
# 2 -0.200494 -0.558919 -0.427912 -0.924069 -1.824118 -1.641621 -1.471255
# 3 -0.026856 -0.558919 -0.677958 -1.295109 -0.888372  0.362013 -1.681993
# 4 -1.068682 -0.418831 -0.928004 -1.542469 -1.289406 -1.140712  0.987362

# %%
import pandas as pd
import numpy as np

# %%
# All our games
number_of_rows = numbers.values.shape[0]
number_of_rows
# Out:
# 2153

# %%
# Amount of games we need to take into consideration for prediction
window_length = 7
window_length
# Out:
# 7

# %%
# Balls counts
number_of_features = numbers.values.shape[1]
number_of_features
# Out:
# 7

# %%
X = np.empty([ (number_of_rows - window_length), window_length, number_of_features], dtype=float)
y = np.empty([ number_of_rows - window_length, number_of_features], dtype=float)
for i in range(0, number_of_rows-window_length):
    X[i] = transformed_df.iloc[i : i+window_length, 0 : number_of_features]
    y[i] = transformed_df.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
X.shape
# Out:
# (2146, 7, 7)

# %%
y.shape
# Out:
# (2146, 7)

# %%
X[0]
# Out:
# array([[-0.37413159,  0.14151895, -0.17786593,  0.06537299, -0.48733785,
#         -0.97374296, -0.48780809],
#        [-0.72140699, -1.11926846,  0.44724891,  0.06537299, -0.08630394,
#         -0.13889564,  0.77662336],
#        [-0.20049388, -0.5589185 , -0.42791187, -0.92406851, -1.82411757,
#         -1.64162082, -1.47125477],
#        [-0.02685618, -0.5589185 , -0.67795781, -1.29510908, -0.88837177,
#          0.36201276, -1.68199334],
#        [-1.0686824 , -0.41883101, -0.92800375, -1.54246945, -1.28940568,
#         -1.14071243,  0.98736194],
#        [ 1.18860774,  0.14151895,  0.32222594,  0.18905318,  0.181052  ,
#         -0.63980403,  0.07416145],
#        [ 0.14678152,  0.56178141,  1.19738673,  0.68377393, -0.08630394,
#          0.69595169,  0.98736194]])

# %%
y[0]
# Out:
# array([ 1.88315855,  1.12213137,  1.19738673,  0.80745412,  1.11679781,
#         0.86292115, -1.33076238])

# %%
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import LSTM
from keras.layers import Dropout

# %%
#4 LSTM layered model
model = Sequential()

# %%
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = False)))
model.add(Dense(59))
model.add(Dense(number_of_features))

# %%
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=X, y=y, batch_size=100, epochs=30, verbose=2)
# Out:
# Epoch 1/30
# 22/22 - 10s - loss: 0.9972 - accuracy: 0.1864 - 10s/epoch - 468ms/step
# Epoch 2/30
# 22/22 - 9s - loss: 0.9968 - accuracy: 0.1743 - 9s/epoch - 430ms/step
# Epoch 3/30
# 22/22 - 10s - loss: 0.9959 - accuracy: 0.1794 - 10s/epoch - 448ms/step
# Epoch 4/30
# 22/22 - 10s - loss: 0.9957 - accuracy: 0.1701 - 10s/epoch - 448ms/step
# Epoch 5/30
# 22/22 - 10s - loss: 0.9952 - accuracy: 0.1887 - 10s/epoch - 446ms/step
# Epoch 6/30
# 22/22 - 10s - loss: 0.9962 - accuracy: 0.1775 - 10s/epoch - 452ms/step
# Epoch 7/30
# 22/22 - 10s - loss: 0.9949 - accuracy: 0.1692 - 10s/epoch - 454ms/step
# Epoch 8/30
# 22/22 - 9s - loss: 0.9934 - accuracy: 0.1733 - 9s/epoch - 423ms/step
# Epoch 9/30
# 22/22 - 10s - loss: 0.9948 - accuracy: 0.1701 - 10s/epoch - 446ms/step
# Epoch 10/30
# 22/22 - 10s - loss: 0.9934 - accuracy: 0.1831 - 10s/epoch - 453ms/step
# Epoch 11/30
# 22/22 - 10s - loss: 0.9927 - accuracy: 0.1757 - 10s/epoch - 456ms/step
# Epoch 12/30
# ...

# %%
to_predict = numbers.tail(8)
to_predict
# Out:
#       Winning Number 1   2   3   4   5   6  Extra Number
# 2145                 4   7   8  20  32  34             24
# 2146                 8  19  24  35  36  40             23
# 2147                10  11  15  18  37  45             26
# 2148                 8  13  18  22  26  42             43
# 2149                 4  20  36  42  46  47             22
# 2150                 2   9  14  24  40  45              3
# 2151                 3  11  14  32  33  42             15
# 2152                 5   8  36  39  42  46             14

# %%
#Remove last row of last 8 mark six
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
to_predict
# Out:
# C:\Users\Don\AppData\Local\Temp\ipykernel_14644\378178569.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
#       Winning Number 1   2   3   4   5   6  Extra Number
# 2145                 4   7   8  20  32  34             24
# 2146                 8  19  24  35  36  40             23
# 2147                10  11  15  18  37  45             26
# 2148                 8  13  18  22  26  42             43
# 2149                 4  20  36  42  46  47             22
# 2150                 2   9  14  24  40  45              3
# 2151                 3  11  14  32  33  42             15

# %%
prediction = numbers.tail(1)
prediction
# Out:
#       Winning Number 1  2   3   4   5   6  Extra Number
# 2152                 5  8  36  39  42  46             14

# %%
to_predict = np.array(to_predict)
to_predict
# Out:
# array([[ 4,  7,  8, 20, 32, 34, 24],
#        [ 8, 19, 24, 35, 36, 40, 23],
#        [10, 11, 15, 18, 37, 45, 26],
#        [ 8, 13, 18, 22, 26, 42, 43],
#        [ 4, 20, 36, 42, 46, 47, 22],
#        [ 2,  9, 14, 24, 40, 45,  3],
#        [ 3, 11, 14, 32, 33, 42, 15]], dtype=int64)

# %%
#Rescale the predictions
scaled_to_predict = scaler.transform(to_predict)
scaled_to_predict
# Out:
# array([[-0.54776929, -0.97918097, -1.67814157, -1.0477487 , -0.48733785,
#         -1.47465136, -0.06633094],
#        [ 0.14678152,  0.7018689 ,  0.32222594,  0.80745412,  0.04737403,
#         -0.47283457, -0.13657713],
#        [ 0.49405693, -0.41883101, -0.80298078, -1.29510908,  0.181052  ,
#          0.36201276,  0.07416145],
#        [ 0.14678152, -0.13865603, -0.42791187, -0.80038832, -1.28940568,
#         -0.13889564,  1.2683467 ],
#        [-0.54776929,  0.84195639,  1.82250158,  1.67321544,  1.38415375,
#          0.69595169, -0.20682332],
#        [-0.8950447 , -0.69900599, -0.92800375, -0.55302795,  0.58208592,
#          0.36201276, -1.54150096],
#        [-0.72140699, -0.41883101, -0.92800375,  0.43641356, -0.35365988,
#         -0.13889564, -0.69854666]])

# %%
y_pred = model.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
# Out:
# 1/1 [==============================] - 7s 7s/step
# The predicted numbers in the last lottery game are: [ 6 14 22 29 36 43 24]

# %%
#The real numbers
prediction = np.array(prediction)
print('The actual numbers in the last lottery game were:', prediction[0])
# Out:
# The actual numbers in the last lottery game were: [ 5  8 36 39 42 46 14]
